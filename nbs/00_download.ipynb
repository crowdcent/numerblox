# %%
#hide
# %load_ext autoreload
# %autoreload 2
# %load_ext nb_black
# %load_ext lab_black

# %%
#default_exp download

# %% [markdown]
# # Download
#
# > Downloaders for Numerai Classic and Numerai Signals.

# %%
#hide
from nbdev.showdoc import *

# %%
#export
import os
import json
import shutil
from numerapi import NumerAPI, SignalsAPI
from pathlib import Path, PosixPath
from abc import ABC, abstractmethod
from rich.tree import Tree
from rich.console import Console
from rich import print as rich_print
from transparentpath import TransparentPath as GCSPath

# %% [markdown]
# ## 1. Base
#
# `BaseDownloader` is an object which implements logic common to all downloaders.
#
# To implement a new Downloader, you should inherit from `BaseDownloader` and be sure to implement at least methods `download_training_data` and `download_inference_data`.

# %%
#export
class BaseDownloader(ABC):
    """
    Abstract base class for downloaders.
    :param directory_path: Base folder to download files to.
    """
    def __init__(self, directory_path: str):
        self.dir = Path(directory_path)
        self._create_directory()

    @abstractmethod
    def download_training_data(self, *args, **kwargs):
        """ Download all necessary files needed for training. """
        raise NotImplementedError(f"No method for downloading training data is implemented in '{self.__class__.__name__}'")

    @abstractmethod
    def download_inference_data(self, *args, **kwargs):
        """ Download minimal amount of files needed for weekly inference. """
        raise NotImplementedError(f"No method for downloading inference data is implemented in '{self.__class__.__name__}'.")

    def remove_base_directory(self):
        """ Remove download directory with all contents. """
        abs_path = self.dir.resolve()
        rich_print(f":warning: [red]Deleting directory for '{self.__class__.__name__}[/red]' :warning:\nPath: '{abs_path}'")
        shutil.rmtree(abs_path)

    def configure_gcs_path(self, bucket_name: str):
        """
        Connect to Google Cloud Storage (GCS) bucket.
        :param bucket_name: Valid GCS bucket that you have access to.

        Credentials are detected automatically with the following process:
        1.The environment variable `GOOGLE_APPLICATION_CREDENTIALS` is set and points to a valid `.json` file.
        2. You have a valid Cloud SDK installation. In that case you might see the warning : UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. It is up to you to decide what to do with it.
        3.The machine running the code is itself a GCP machine.
        """
        GCSPath.set_global_fs("gcs", bucket=bucket_name)
        self.dir = GCSPath(self.dir)
        self._create_directory()
        rich_print(f":cloud: Path {self.dir} configured for Google Cloud Storage. :cloud:")

    def _append_folder(self, folder: str) -> Path:
        """
        Return base directory appended with 'folder'.
        Create directory if it does not exist.
        """
        dir = Path(self.dir / folder)
        dir.mkdir(parents=True, exist_ok=True)
        return dir

    @staticmethod
    def _load_json(file_path: str, verbose = False, *args, **kwargs) -> dict:
        """ Load JSON from file and return as dictionary. """
        with open(file_path) as json_file:
            json_data = json.load(json_file, *args, **kwargs)
        if verbose:
            rich_print(json_data)
        return json_data

    def _create_directory(self):
        """ Create base directory if it does not exist. """
        if not self.dir.is_dir():
            rich_print(f"No existing directory found at '[blue]{self.dir}[/blue]'. Creating directory...")
            self.dir.mkdir(parents=True, exist_ok=True)

    @property
    def get_all_files(self) -> list:
        """ Return all contents in directory. """
        return list(self.dir.iterdir())

    @property
    def is_empty(self) -> bool:
        """ Check if directory is empty."""
        return not bool(self.get_all_files)

    def __call__(self, *args, **kwargs):
        """
        The most common use case will be to get weekly inference data. So calling the class itself returns inference data.
        """
        self.download_inference_data(*args, **kwargs)

# %% [markdown]
# ## 2. Numerai Classic

# %%
#export
class NumeraiClassicDownloader(BaseDownloader):
    """
    Downloading from NumerAPI for Numerai Classic data

    :param directory_path: Base folder to download files to.
    All *args, **kwargs will be passed to NumerAPI initialization.
    """
    def __init__(self, directory_path: str, *args, **kwargs):
        super(NumeraiClassicDownloader, self).__init__(directory_path=directory_path)
        self.napi = NumerAPI(*args, **kwargs)
        self.current_round = self.napi.get_current_round()
        # NumerAPI filenames corresponding to version, class and data type
        self.version_mapping = {1: {"train":
                                        {"int8": ['numerai_training_data_int8.csv', 'numerai_validation_data_int8.csv'],
                                         "float": ['numerai_training_data.csv', 'numerai_validation_data.csv']},
                                    "inference": {"int8": ['numerai_tournament_data_int8.csv'],
                                                  "float": ['numerai_tournament_data.csv']},
                                    "example": ['example_predictions.csv', 'example_validation_predictions.csv']},
                                2: {"train":
                                        {"int8": ['numerai_training_data_int8.parquet', 'numerai_validation_data_int8.parquet'],
                                         "float": ['numerai_training_data.parquet', 'numerai_validation_data.parquet']},
                                    "inference": {"int8": ['numerai_tournament_data_int8.parquet'],
                                                  "float": ['numerai_tournament_data.parquet']},
                                    "example": ['example_predictions.parquet', 'example_validation_predictions.parquet']}
                                }

    def download_training_data(self, subfolder: str = "", version: int = 2, int8: bool = False):
        """
        Get Numerai classic training and validation data.
        :param subfolder: Specify folder to create folder within directory root. Saves in directory root by default.
        :param version: Numerai version (1=classic, 2=super massive dataset (parquet)
        :param int8: Integer version of data
        """
        dir = self._append_folder(subfolder)
        data_type = "int8" if int8 else "float"
        train_val_files = self._get_version_mapping(version)['train'][data_type]
        for file in train_val_files:
            self.download_single_dataset(filename=file,
                                         dest_path=str(dir.joinpath(file)))


    def download_inference_data(self, subfolder: str = "", version: int = 2, int8: bool = False, round_num: int = None):
        """
        Get Numerai classic inference data.
        :param subfolder: Specify folder to create folder within directory root. Saves in directory root by default.
        :param version: Numerai version (1=classic, 2=super massive dataset (parquet)
        :param int8: Integer version of data
        :param round_num: Numerai tournament round number. Downloads latest round by default.
        """
        dir = self._append_folder(subfolder)
        data_type = "int8" if int8 else "float"
        inference_files = self._get_version_mapping(version)['inference'][data_type]
        rich_print(f":file_folder: [green]Downloading inference data for round[/green] '{round_num if round_num else self.current_round}'.")
        for file in inference_files:
            self.download_single_dataset(filename=file,
                                         dest_path=str(dir.joinpath(file)),
                                         round_num=round_num)

    def download_single_dataset(self, filename: str, dest_path: str, round_num: int = None):
        """
        Download one of the available datasets through NumerAPI.

        :param filename: Name as listed in NumerAPI (Check NumerAPI().list_datasets())
        :param dest_path: Full path where file will be saved.
        :param round_num: Numerai tournament round number. Downloads latest round by default.
        """
        assert filename in self.napi.list_datasets(), f"Dataset '{filename}' not available in NumerAPI. Available datasets are {self.napi.list_datasets()}."
        rich_print(f":file_folder: [green]Downloading[/green] '{filename}' :file_folder:")
        self.napi.download_dataset(filename=filename,
                                   dest_path=dest_path,
                                   round_num=round_num)


    def download_example_data(self, subfolder: str = "", version: int = 2, round_num: int = None):
        """
        Download all example prediction data in specified folder for given version.

        :param subfolder: Specify folder to create folder within directory root. Saves in directory root by default.
        :param version: Numerai version (1=classic, 2=super massive dataset (parquet)
        :param round_num: Numerai tournament round number. Downloads latest round by default.
        """
        dir = self._append_folder(subfolder)
        example_files = self._get_version_mapping(version)['example']
        for file in example_files:
            self.download_single_dataset(filename=file,
                                         dest_path=str(dir.joinpath(file)),
                                         round_num=round_num)

    def get_classic_features(self, subfolder: str = "", *args, **kwargs) -> dict:
        """
        Download feature overview (stats and feature sets) through NumerAPI and load.
        :param subfolder: Specify folder to create folder within directory root. Saves in directory root by default.
        *args, **kwargs will be passed to the JSON loader.
        """
        dir = self._append_folder(subfolder)
        filename = "features.json"
        dest_path = str(dir.joinpath(filename))
        self.download_single_dataset(filename=filename,
                                     dest_path=dest_path)
        json_data = self._load_json(dest_path, *args, **kwargs)
        return json_data

    def _get_version_mapping(self, version: int) -> dict:
        """ Check if version is supported and return file mapping for version. """
        try:
            mapping_dictionary = self.version_mapping[version]
        except KeyError:
            raise NotImplementedError(f"Version '{version}' is not implemented. Available versions are {list(self.version_mapping.keys())}")
        return mapping_dictionary

# %% [markdown]
# ### NumeraiClassicDownlaoder and BaseDownloader tests

# %%
#slow
test_dir_classic = "test_numclassic_general"
numer_classic_downloader = NumeraiClassicDownloader(test_dir_classic)

# Test building class
assert isinstance(numer_classic_downloader.dir, PosixPath)
assert numer_classic_downloader.dir.is_dir()

# Test is_empty
(numer_classic_downloader.dir / "test.txt").write_text("test")
rich_print(f"Directory contents:\n{numer_classic_downloader.get_all_files}")
assert not numer_classic_downloader.is_empty

# Downloading example data
numer_classic_downloader.download_example_data("test1/", version=1)
numer_classic_downloader.download_example_data("test2/", version=2, round_num=290)

# Features
feature_stats_test = numer_classic_downloader.get_classic_features()
assert isinstance(feature_stats_test, dict)
assert len(feature_stats_test['feature_sets']['legacy']) == 304

# Remove contents
numer_classic_downloader.remove_base_directory()
assert not os.path.exists(test_dir_classic)
# Out:
# No existing directory found at 'test_numclassic_general'. Creating directory...
# Directory contents:
# [Path('test_numclassic_general/test.txt')]
# 📁 Downloading 'example_predictions.csv' 📁
# 2022-01-06 13:07:00,854 INFO numerapi.utils: starting download
# test_numclassic_general/test1/example_predictions.csv: 51.2MB [00:24, 2.13MB/s]
# 📁 Downloading 'example_validation_predictions.csv' 📁
# 2022-01-06 13:07:26,689 INFO numerapi.utils: starting download
# test_numclassic_general/test1/example_validation_predictions.csv: 19.6MB [00:04, 4.61MB/s]
# 📁 Downloading 'example_predictions.parquet' 📁
# 2022-01-06 13:07:33,721 INFO numerapi.utils: starting download
# test_numclassic_general/test2/example_predictions.parquet: 33.5MB [00:35, 954kB/s]
# 📁 Downloading 'example_validation_predictions.parquet' 📁
# 2022-01-06 13:08:11,208 INFO numerapi.utils: starting download
# test_numclassic_general/test2/example_validation_predictions.parquet: 13.0MB [00:03, 4.26MB/s]
# 📁 Downloading 'features.json' 📁
# 2022-01-06 13:08:15,869 INFO numerapi.utils: starting download
# test_numclassic_general/features.json: 441kB [00:00, 615kB/s]
# ⚠ Deleting directory for 'NumeraiClassicDownloader' ⚠
# Path:
# '/Users/clepelaars/Desktop/crowdcent/repositories/numerai-blocks/nbs/test_numclassic_general'

# %% [markdown]
# ### Example usage

# %% [markdown]
# #### Training

# %%
#slow
# Initialization
train_base_directory = "test_numclassic_train"
numer_classic_downloader = NumeraiClassicDownloader(train_base_directory)

# Uncomment line below to download training and validation data.
# numer_classic_downloader.download_training_data("train_val", version=2, int8=False)

# Get feature overview
numer_classic_downloader.get_classic_features();
# Out:
# No existing directory found at 'test_numclassic_train'. Creating directory...
# 📁 Downloading 'features.json' 📁
# 2022-01-06 13:08:19,130 INFO numerapi.utils: starting download
# test_numclassic_train/features.json: 441kB [00:00, 608kB/s]
# {'feature_stats': {'feature_dichasial_hammier_spawner': {'legacy_uniqueness': 0.1778140232616494,
#    'spearman_corr_w_target_nomi_20_mean': -0.0006870366768374209,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.06827874939205324,
#    'spearman_corr_w_target_nomi_20_reversals': 7.490937957833377e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.021193429374978014,
#    'spearman_corr_w_target_nomi_20_arl': 3.3248407643312103},
#   'feature_rheumy_epistemic_prancer': {'legacy_uniqueness': 0.2413505596136356,
#    'spearman_corr_w_target_nomi_20_mean': 0.00024874591501294137,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.02533555481334663,
#    'spearman_corr_w_target_nomi_20_reversals': 8.392516152487414e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.10173904070244294,
#    'spearman_corr_w_target_nomi_20_arl': 3.2830188679245285},
#   'feature_pert_performative_hormuz': {'legacy_uniqueness': 0.6590919790936269,
#    'spearman_corr_w_target_nomi_20_mean': -0.0005876714655874945,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.06419272197197065,
#    'spearman_corr_w_target_nomi_20_reversals': 6.706499983902339e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.03406886977545209,
#    'spearman_corr_w_target_nomi_20_arl': 3.125748502994012},
#   'feature_hillier_unpitied_theobromine': {'legacy_uniqueness': 0.2349938825719049,
#    'spearman_corr_w_target_nomi_20_mean': 0.0017632891460612305,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.13079528252067066,
#    'spearman_corr_w_target_nomi_20_reversals': 9.24186917847952e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.14866131377098193,
#    'spearman_corr_w_target_nomi_20_arl': 4.176},
#   'feature_perigean_bewitching_thruster': {'legacy_uniqueness': 0.47105084274328834,
#    'spearman_corr_w_target_nomi_20_mean': 0.0006961090796738962,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.06866431322387526,
#    'spearman_corr_w_target_nomi_20_reversals': 7.314375648242577e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.015733707921960823,
#    'spearman_corr_w_target_nomi_20_arl': 3.7553956834532376},
#   'feature_renegade_undomestic_milord': {'legacy_uniqueness': 0.608925631229952,
#    'spearman_corr_w_target_nomi_20_mean': -0.0015677795178473078,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.1765524838961793,
#    'spearman_corr_w_target_nomi_20_reversals': 5.9700085920134845e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.01907645000576775,
#    'spearman_corr_w_target_nomi_20_arl': 3.2830188679245285},
#   'feature_koranic_rude_corf': {'legacy_uniqueness': 0.2208836295673674,
#    'spearman_corr_w_target_nomi_20_mean': -0.0006689471715609165,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.09027149441452505,
#    'spearman_corr_w_target_nomi_20_reversals': 5.1529259062298524e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.059501803319321214,
#    'spearman_corr_w_target_nomi_20_arl': 3.3037974683544302},
#   'feature_demisable_expiring_millepede': {'legacy_uniqueness': 0.6718972340542373,
#    'spearman_corr_w_target_nomi_20_mean': -0.0035145511667540675,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.32951300871136785,
#    'spearman_corr_w_target_nomi_20_reversals': 7.467380909996217e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.09267482261290727,
#    'spearman_corr_w_target_nomi_20_arl': 3.625},
#   'feature_unscheduled_malignant_shingling': {'legacy_uniqueness': 0.8788999685581409,
#    'spearman_corr_w_target_nomi_20_mean': -0.00013680991673380776,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.012134208699799464,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00010724428117229262,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.03658369283678618,
#    'spearman_corr_w_target_nomi_20_arl': 3.2422360248447206},
#   'feature_clawed_unwept_adaptability': {'legacy_uniqueness': 0.174533363461584,
#    'spearman_corr_w_target_nomi_20_mean': -0.0019094492488067913,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.17465047790502805,
#    'spearman_corr_w_target_nomi_20_reversals': 8.734431859021243e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.1195237235419654,
#    'spearman_corr_w_target_nomi_20_arl': 3.7553956834532376},
#   'feature_rubblier_chlorotic_stogy': {'legacy_uniqueness': 0.4126516754843085,
#    'spearman_corr_w_target_nomi_20_mean': 0.0009805891273666212,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.08194153883121981,
#    'spearman_corr_w_target_nomi_20_reversals': 8.482140564794107e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.023707007386542904,
#    'spearman_corr_w_target_nomi_20_arl': 4.046511627906977},
#   'feature_untumbled_histologic_inion': {'legacy_uniqueness': 0.6894729485592147,
#    'spearman_corr_w_target_nomi_20_mean': 0.0006635822760214915,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.06298434249873028,
#    'spearman_corr_w_target_nomi_20_reversals': 9.243395879449614e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.08951928618392686,
#    'spearman_corr_w_target_nomi_20_arl': 3.182926829268293},
#   'feature_piffling_inflamed_jupiter': {'legacy_uniqueness': 0.7698268012211533,
#    'spearman_corr_w_target_nomi_20_mean': -0.0007668635887143096,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.12281423959782721,
#    'spearman_corr_w_target_nomi_20_reversals': 3.7404344687892225e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.04995355766113969,
#    'spearman_corr_w_target_nomi_20_arl': 2.916201117318436},
#   'feature_abstersive_emotional_misinterpreter': {'legacy_uniqueness': 0.864488151291823,
#    'spearman_corr_w_target_nomi_20_mean': 0.0038840145241103353,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.24907776861417066,
#    'spearman_corr_w_target_nomi_20_reversals': 0.000135206325192671,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.14429892075121747,
#    'spearman_corr_w_target_nomi_20_arl': 4.539130434782609},
#   'feature_unluckiest_mulley_benzyl': {'legacy_uniqueness': 0.7953602072793491,
#    'spearman_corr_w_target_nomi_20_mean': 0.0030190656308934924,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.2628726230490975,
#    'spearman_corr_w_target_nomi_20_reversals': 9.608892256660862e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.08151194085887173,
#    'spearman_corr_w_target_nomi_20_arl': 3.456953642384106},
#   'feature_escutcheoned_timocratic_kotwal': {'legacy_uniqueness': 0.8404551057854177,
#    'spearman_corr_w_target_nomi_20_mean': 0.0021677501106538307,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.15410229747577614,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00011904592157052605,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.06937199137693628,
#    'spearman_corr_w_target_nomi_20_arl': 3.702127659574468},
#   'feature_integrated_extroversive_ambivalence': {'legacy_uniqueness': 0.7970016109811264,
#    'spearman_corr_w_target_nomi_20_mean': 0.0024299153584320266,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.248400732824631,
#    'spearman_corr_w_target_nomi_20_reversals': 7.5742994544785e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.0026541263235851306,
#    'spearman_corr_w_target_nomi_20_arl': 3.4342105263157894},
#   'feature_vedic_mitral_swiz': {'legacy_uniqueness': 0.8094633629993502,
#    'spearman_corr_w_target_nomi_20_mean': -0.009559834569849792,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.3629368425367291,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0003545214815061715,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.012821850995869391,
#    'spearman_corr_w_target_nomi_20_arl': 4.31404958677686},
#   'feature_reclaimed_fallibilist_turpentine': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.0061985004495264525,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.2965564304028776,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00026508139565560715,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.05438720127480797,
#    'spearman_corr_w_target_nomi_20_arl': 4.176},
#   'feature_gone_honduran_worshipper': {'legacy_uniqueness': 0.6200025848685673,
#    'spearman_corr_w_target_nomi_20_mean': 0.003142879467910515,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.14433788435776393,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00029033932732917687,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.07585419555357138,
#    'spearman_corr_w_target_nomi_20_arl': 4.35},
#   'feature_insociable_exultant_tatum': {'legacy_uniqueness': 0.3962848611584313,
#    'spearman_corr_w_target_nomi_20_mean': -0.002627093663569694,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.12928956829658314,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00023704065288381376,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.03071002270836915,
#    'spearman_corr_w_target_nomi_20_arl': 4.015384615384615},
#   'feature_outdated_tapered_speciation': {'legacy_uniqueness': 0.3200287477681879,
#    'spearman_corr_w_target_nomi_20_mean': -0.002152032345206202,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.11479936586189618,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00021260347802130758,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.05241368655811155,
#    'spearman_corr_w_target_nomi_20_arl': 3.8955223880597014},
#   'feature_leggiest_slaggiest_inez': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.0016310136053669612,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.08669279412516863,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00020878722292668315,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.10121007529271547,
#    'spearman_corr_w_target_nomi_20_arl': 3.8666666666666667},
#   'feature_chaldean_vixenly_propylite': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.0006551112566027262,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.03540684910353633,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00020548611042535617,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.026801205292393472,
#    'spearman_corr_w_target_nomi_20_arl': 3.7553956834532376},
#   'feature_hysteric_mechanized_recklinghausen': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0024732578906588288,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.09525184818788955,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0003650430399488774,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.1311927742224096,
#    'spearman_corr_w_target_nomi_20_arl': 4.2439024390243905},
#   'feature_glare_factional_assessment': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.0025306126860740043,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.22641556639322047,
#    'spearman_corr_w_target_nomi_20_reversals': 9.284899534525667e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.0077424904028678175,
#    'spearman_corr_w_target_nomi_20_arl': 3.5510204081632653},
#   'feature_highland_eocene_berean': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -7.970100471990328e-05,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.006547806919972364,
#    'spearman_corr_w_target_nomi_20_reversals': 9.848576951068059e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.04281115976790726,
#    'spearman_corr_w_target_nomi_20_arl': 3.2830188679245285},
#   'feature_seemlier_reorient_monandry': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0029196291063328566,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.16548466165987513,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00021900870697893942,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.09712269231483066,
#    'spearman_corr_w_target_nomi_20_arl': 3.411764705882353},
#   'feature_expressed_abhominable_pruning': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.002938993121366532,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.17089826207990466,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002157125739823503,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.06441324142704612,
#    'spearman_corr_w_target_nomi_20_arl': 3.5753424657534247},
#   'feature_castrated_presented_quizzer': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.007850125432122622,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.43205267871033204,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00021321937799019335,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.04200326462928806,
#    'spearman_corr_w_target_nomi_20_arl': 3.625},
#   'feature_restricted_aggregately_workmanship': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.002097820508515846,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.10669352195238023,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002060857496644131,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.11067570575380499,
#    'spearman_corr_w_target_nomi_20_arl': 4.619469026548672},
#   'feature_scorbutic_intellectualism_mongoloid': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.002042453988842402,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.08128510081785469,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00033558960779009626,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.06506558758601307,
#    'spearman_corr_w_target_nomi_20_arl': 4.5},
#   'feature_telephonic_shakable_bollock': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.004058937373530835,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.23183169324161504,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002346922186672489,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.009104594010268837,
#    'spearman_corr_w_target_nomi_20_arl': 3.456953642384106},
#   'feature_subglobular_unsalable_patzer': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.008592551529664738,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.485456231672137,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00021563148360286417,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.06316346516089671,
#    'spearman_corr_w_target_nomi_20_arl': 3.411764705882353},
#   'feature_syrian_coital_counterproof': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.006357527405203193,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.3613133046072154,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002277029841396826,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.05735316671710747,
#    'spearman_corr_w_target_nomi_20_arl': 3.9545454545454546},
#   'feature_supergene_legible_antarthritic': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.008974290924764764,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.5398524727087181,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00019280337792701433,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.04380655657104913,
#    'spearman_corr_w_target_nomi_20_arl': 4.015384615384615},
#   'feature_hypothetic_distressing_endemic': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.004247339332169466,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.26221087933179116,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00018943060183486125,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.1566556666149761,
#    'spearman_corr_w_target_nomi_20_arl': 3.6},
#   'feature_torturesome_estimable_preferrer': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.0007115471379440995,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.03829716684586485,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00023679270293343218,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.16939671283747107,
#    'spearman_corr_w_target_nomi_20_arl': 3.702127659574468},
#   'feature_greedier_favorable_enthymeme': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.0009929208829061252,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.05532004221380865,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00022656920636027122,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.10712812352062086,
#    'spearman_corr_w_target_nomi_20_arl': 3.81021897810219},
#   'feature_decent_solo_stickup': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 6.724253627948107e-05,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.0031426185642762948,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00027069851834183353,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.0409428803909438,
#    'spearman_corr_w_target_nomi_20_arl': 3.8955223880597014},
#   'feature_unmalleable_resistant_kingston': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.0036360797381569322,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.26174050624236483,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00014758150568027202,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.019626916887414702,
#    'spearman_corr_w_target_nomi_20_arl': 3.8955223880597014},
#   'feature_seamier_jansenism_inflator': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.004403912212951023,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.2607682592319182,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002209214511844604,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.061632613374116504,
#    'spearman_corr_w_target_nomi_20_arl': 3.125748502994012},
#   'feature_lordly_lamellicorn_buxtehude': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.003414541559332589,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.25456639847818563,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00013437671420861382,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.030000870236648682,
#    'spearman_corr_w_target_nomi_20_arl': 3.7285714285714286},
#   'feature_mattery_past_moro': {'legacy_uniqueness': 0.20948438543503356,
#    'spearman_corr_w_target_nomi_20_mean': -0.0036681104002121126,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.28698873382756745,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00010871695409974561,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.014133333524979943,
#    'spearman_corr_w_target_nomi_20_arl': 3.676056338028169},
#   'feature_helpable_chanciest_fractionisation': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0014857250844786767,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.0917926333161548,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00017576457189434478,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.11588102448289304,
#    'spearman_corr_w_target_nomi_20_arl': 3.6503496503496504},
#   'feature_spookiest_expedite_overnighter': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.006767254917231348,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.5019605980955777,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0001473898483535791,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.08192616351350028,
#    'spearman_corr_w_target_nomi_20_arl': 3.2830188679245285},
#   'feature_culinary_pro_offering': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.002304163007427324,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.2000325363266419,
#    'spearman_corr_w_target_nomi_20_reversals': 9.832034802837474e-05,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.0908531563696066,
#    'spearman_corr_w_target_nomi_20_arl': 3.6},
#   'feature_ganoid_osiered_mineralogy': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0007491164208401003,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.04226553022497464,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00023913851027585373,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.08084573922982334,
#    'spearman_corr_w_target_nomi_20_arl': 3.1636363636363636},
#   'feature_hotfoot_behaviorist_terylene': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0016422215792280172,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.11352207165309905,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0001442471995454072,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.06806537235246654,
#    'spearman_corr_w_target_nomi_20_arl': 3.6},
#   'feature_severe_tricky_pinochle': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.0008241447783039647,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.04768189436242614,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00019393680246163427,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.07660752870289456,
#    'spearman_corr_w_target_nomi_20_arl': 3.5033557046979866},
#   'feature_maximal_unobserving_desalinisation': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0032793451443654696,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.20646675234442585,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0001794278515104593,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.06235218955276009,
#    'spearman_corr_w_target_nomi_20_arl': 3.5510204081632653},
#   'feature_voltairean_consolidative_parallel': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.005217732170741195,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.28282599096897365,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00020203945563398656,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.025638848052954483,
#    'spearman_corr_w_target_nomi_20_arl': 3.838235294117647},
#   'feature_unmoved_alt_spoonerism': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.005003350372406493,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.2846614706075417,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00022989512959095714,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.015795835519562856,
#    'spearman_corr_w_target_nomi_20_arl': 3.5033557046979866},
#   'feature_tittering_virgilian_decliner': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.005210059189795265,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.29136918078399004,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00020181230260822456,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.09252994903563318,
#    'spearman_corr_w_target_nomi_20_arl': 4.110236220472441},
#   'feature_methylated_necrophilic_serendipity': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0037918418551477397,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.21160172516323128,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00021586334572160017,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.0070283920885158575,
#    'spearman_corr_w_target_nomi_20_arl': 3.782608695652174},
#   'feature_calceolate_pudgy_armure': {'legacy_uniqueness': 0.7229409920139049,
#    'spearman_corr_w_target_nomi_20_mean': 0.0008256491136866308,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.03905663583857021,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00022063614881228172,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.18429205297297566,
#    'spearman_corr_w_target_nomi_20_arl': 4.046511627906977},
#   'feature_unsparing_moralistic_commissary': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.006493104634254359,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.3352618640158974,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0001775257586718523,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.19834356490812743,
#    'spearman_corr_w_target_nomi_20_arl': 4.176},
#   'feature_criticisable_authentical_deprecation': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0102631258043679,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.4385967998494024,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00022438524614994457,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.26184910774408854,
#    'spearman_corr_w_target_nomi_20_arl': 5.1683168316831685},
#   'feature_undetermined_idle_aftergrowth': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0013382571996304823,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.0797668258358508,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00018241385917047657,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.047097155758245475,
#    'spearman_corr_w_target_nomi_20_arl': 3.782608695652174},
#   'feature_antipathetical_terrorful_ife': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.002466123555785655,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.15317060017405854,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0001874502116589676,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.012767295661889794,
#    'spearman_corr_w_target_nomi_20_arl': 3.702127659574468},
#   'feature_caressive_cognate_cubature': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.001392630014671341,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.10088890198688073,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00013607983650403246,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.04830827576683086,
#    'spearman_corr_w_target_nomi_20_arl': 3.5753424657534247},
#   'feature_crablike_panniered_gloating': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0014638647406252099,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.10529397505151185,
#    'spearman_corr_w_target_nomi_20_reversals': 0.000143149962344556,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.06519227055946583,
#    'spearman_corr_w_target_nomi_20_arl': 3.4342105263157894},
#   'feature_exacerbating_presentationism_apagoge': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.00660130164136069,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.3366005874687846,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00018826475487904634,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.18800712512894338,
#    'spearman_corr_w_target_nomi_20_arl': 4.046511627906977},
#   'feature_epicurean_fetal_seising': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.000868135795341728,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.05252306437975011,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00019599321611474973,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.05237226984128112,
#    'spearman_corr_w_target_nomi_20_arl': 3.48},
#   'feature_casuistic_barbarian_monochromy': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.00010175755586790509,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.005605037094256348,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00017997027495700579,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.03238357572257507,
#    'spearman_corr_w_target_nomi_20_arl': 4.539130434782609},
#   'feature_haematoid_runaway_nightjar': {'legacy_uniqueness': 0.6213783091432006,
#    'spearman_corr_w_target_nomi_20_mean': 0.002802000466917695,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.14252067756243336,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002522615396560155,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.05717255371922626,
#    'spearman_corr_w_target_nomi_20_arl': 3.924812030075188},
#   'feature_croupiest_shaded_thermotropism': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.002540754507791277,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.15097867931896908,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00020104684360625243,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.028606342761373443,
#    'spearman_corr_w_target_nomi_20_arl': 3.527027027027027},
#   'feature_zarathustrian_albigensian_itch': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.004296014859778835,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.21392450866501692,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00025273776825386927,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.07216421639534171,
#    'spearman_corr_w_target_nomi_20_arl': 3.5033557046979866},
#   'feature_unsparred_scarabaeid_anthologist': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0019555572574865886,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.09973585693244455,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00029309361224311257,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.043718756032717236,
#    'spearman_corr_w_target_nomi_20_arl': 3.367741935483871},
#   'feature_unco_terefah_thirster': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.005750687841751145,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.3306028222459123,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00022835943195447103,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.04412510478476131,
#    'spearman_corr_w_target_nomi_20_arl': 3.5753424657534247},
#   'feature_sallowish_cognisant_romaunt': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.005517192392103452,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.2858747069853924,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00028076041075088097,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.05157625782910747,
#    'spearman_corr_w_target_nomi_20_arl': 3.411764705882353},
#   'feature_grazed_blameful_desiderative': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0043310277826276,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.20216692755447627,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0003375123036737504,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.006541816004998517,
#    'spearman_corr_w_target_nomi_20_arl': 3.7553956834532376},
#   'feature_whitened_remanent_blast': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.007910057531710963,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.4252866488906371,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002864862253421073,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.018193953995571884,
#    'spearman_corr_w_target_nomi_20_arl': 3.3461538461538463},
#   'feature_introvert_symphysial_assegai': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.009727286324873446,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.538191581836967,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00025156441198488877,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.07299449492910262,
#    'spearman_corr_w_target_nomi_20_arl': 3.411764705882353},
#   'feature_casemated_ibsenian_grantee': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.008492949166734846,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.43701996479237615,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00028042330410871165,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.007346599081605766,
#    'spearman_corr_w_target_nomi_20_arl': 3.676056338028169},
#   'feature_intertwined_leeriest_suffragette': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.004986771850911244,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.23189190852114439,
#    'spearman_corr_w_target_nomi_20_reversals': 0.000275378914678924,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.03437024529495775,
#    'spearman_corr_w_target_nomi_20_arl': 4.046511627906977},
#   'feature_built_reincarnate_sherbet': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.008572778970896642,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.3897875600565799,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00030799688240189005,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.025881863054175062,
#    'spearman_corr_w_target_nomi_20_arl': 3.7553956834532376},
#   'feature_axillary_reluctant_shorty': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.008020057153931984,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.3558708674572705,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00029411468086187545,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.026653542232633266,
#    'spearman_corr_w_target_nomi_20_arl': 4.2439024390243905},
#   'feature_descendent_decanal_hon': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.005318290645772143,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.24842479472030424,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00030268708511513347,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.053954600906777665,
#    'spearman_corr_w_target_nomi_20_arl': 4.046511627906977},
#   'feature_untrimmed_monaxial_accompanist': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.009341307335065809,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.40699638745930145,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00031536726480428564,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.06884764591137646,
#    'spearman_corr_w_target_nomi_20_arl': 3.8666666666666667},
#   'feature_desiderative_commiserative_epizoa': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.007462940128803331,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.3154562218330205,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00032584104170895525,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.04752122685657508,
#    'spearman_corr_w_target_nomi_20_arl': 4.176},
#   'feature_subdued_spiffier_kano': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.004570499679898705,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.20287574599923938,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0003094554809189093,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.02007304937085234,
#    'spearman_corr_w_target_nomi_20_arl': 4.209677419354839},
#   'feature_affricative_bromic_raftsman': {'legacy_uniqueness': 0.8254985518682711,
#    'spearman_corr_w_target_nomi_20_mean': 0.002505443887325625,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.1662957421798968,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00016672688206766076,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.13129555421212716,
#    'spearman_corr_w_target_nomi_20_arl': 3.4342105263157894},
#   'feature_doggish_whacking_headscarf': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.00880146748654686,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.36319213145272494,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0003283754204665484,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.012572495116030959,
#    'spearman_corr_w_target_nomi_20_arl': 4.31404958677686},
#   'feature_congenital_conched_perithecium': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.010274315774339123,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.47753182784611,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002928705372174727,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.020934181652440334,
#    'spearman_corr_w_target_nomi_20_arl': 4.209677419354839},
#   'feature_terrific_epigamic_affectivity': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.0034324417258318625,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.16509743173638367,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002584326935855566,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.0077621258437372215,
#    'spearman_corr_w_target_nomi_20_arl': 3.7285714285714286},
#   'feature_enlightening_mirthful_laurencin': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0028260774799394304,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.1742295193755439,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00025935238147099137,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.010944875666154192,
#    'spearman_corr_w_target_nomi_20_arl': 2.9491525423728815},
#   'feature_continuate_unprocurable_haversine': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.002795068632722053,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.17684235682079139,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00023207065265220178,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.05369640824645453,
#    'spearman_corr_w_target_nomi_20_arl': 3.6},
#   'feature_fustiest_voiced_janet': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0027299502932587837,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.15379926673661082,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002512675403375794,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.013237626709835967,
#    'spearman_corr_w_target_nomi_20_arl': 3.182926829268293},
#   'feature_ovular_powered_neckar': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0014716635098527967,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.08783500575798264,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00020733902893902678,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.06620426554140008,
#    'spearman_corr_w_target_nomi_20_arl': 3.456953642384106},
#   'feature_questionable_diplex_caesarist': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.01066112222242371,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.4612301231309912,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00031669469697152315,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.04499399059591117,
#    'spearman_corr_w_target_nomi_20_arl': 3.8955223880597014},
#   'feature_nubblier_plosive_deepening': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.008825297542000551,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.3779594845436002,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002808260451364783,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.09721774242903893,
#    'spearman_corr_w_target_nomi_20_arl': 4.176},
#   'feature_revitalizing_dashing_photomultiplier': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.00966299207225266,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.5402275369091983,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002315683566390515,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.007713175482752101,
#    'spearman_corr_w_target_nomi_20_arl': 3.8955223880597014},
#   'feature_chafed_undenominational_backstitch': {'legacy_uniqueness': 0.8380851793696242,
#    'spearman_corr_w_target_nomi_20_mean': 0.002456012744440239,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.1551251641150426,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00016390108221511329,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.08376009521171918,
#    'spearman_corr_w_target_nomi_20_arl': 3.81021897810219},
#   'feature_assenting_darn_arthropod': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.010651546856370429,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.5331792462558292,
#    'spearman_corr_w_target_nomi_20_reversals': 0.000268840529233289,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.04905961322321911,
#    'spearman_corr_w_target_nomi_20_arl': 3.456953642384106},
#   'feature_consecrate_legislative_cavitation': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.004656597961456128,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.27981124855864775,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00017278777347676155,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.016038433251349172,
#    'spearman_corr_w_target_nomi_20_arl': 3.527027027027027},
#   'feature_inhabited_pettier_veinlet': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.006484606289845353,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.3164454700516077,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002935194425279877,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.02972290032888482,
#    'spearman_corr_w_target_nomi_20_arl': 3.702127659574468},
#   'feature_voltairean_dyslogistic_epagoge': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.010177684508313946,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.4646946486446416,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002851166694489001,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.06523173697144573,
#    'spearman_corr_w_target_nomi_20_arl': 4.2439024390243905},
#   'feature_log_unregenerate_babel': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.011177711140372578,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.5309302853550354,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00032329443138225886,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.11387055667491658,
#    'spearman_corr_w_target_nomi_20_arl': 3.411764705882353},
#   'feature_agile_unrespited_gaucho': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.009473729390719639,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.43078284489542984,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00028195709176623746,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.03268114108623066,
#    'spearman_corr_w_target_nomi_20_arl': 4.31404958677686},
#   'feature_whopping_eminent_attempter': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.005353010872611516,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.2767577254226732,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002571134747927081,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.0018999260824569392,
#    'spearman_corr_w_target_nomi_20_arl': 3.676056338028169},
#   'feature_travelled_semipermeable_perruquier': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.007548942690450574,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.37728521278853727,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002540542381479403,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.02250597214302839,
#    'spearman_corr_w_target_nomi_20_arl': 3.7285714285714286},
#   'feature_horizontal_snug_description': {'legacy_uniqueness': 0.6061275634008345,
#    'spearman_corr_w_target_nomi_20_mean': 0.0005148673028324248,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.035506834221092944,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00015162976382411991,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.02418191904795864,
#    'spearman_corr_w_target_nomi_20_arl': 3.676056338028169},
#   'feature_inhibited_snowiest_drawing': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0011948207278229465,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.07383879082417438,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00016496640620269364,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.09280033746614043,
#    'spearman_corr_w_target_nomi_20_arl': 3.3248407643312103},
#   'feature_salian_suggested_ephemeron': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0019751738488926695,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.11436953890865416,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00023810907247326794,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.10322792700422115,
#    'spearman_corr_w_target_nomi_20_arl': 3.5753424657534247},
#   'feature_diverticular_punjabi_matronship': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0089722542437278,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.4317263688077299,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00029232231962265687,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.03660601284150308,
#    'spearman_corr_w_target_nomi_20_arl': 3.7285714285714286},
#   'feature_reminiscent_unpained_ukulele': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.009804928660032727,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.4569582512045201,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002873029068764257,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.01416036137158713,
#    'spearman_corr_w_target_nomi_20_arl': 3.8955223880597014},
#   'feature_unsurveyed_chopped_feldspathoid': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0013412275939634164,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.05326757377190658,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00036140789630681827,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.16402061993159398,
#    'spearman_corr_w_target_nomi_20_arl': 4.35},
#   'feature_degenerate_officinal_feasibility': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.001870756105534512,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.07143426454085418,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0003805901984539095,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.11346319253472875,
#    'spearman_corr_w_target_nomi_20_arl': 4.5},
#   'feature_undrossy_serpentiform_sack': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.005469187152362891,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.18040500143597038,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0005144452506691572,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.07425818026529424,
#    'spearman_corr_w_target_nomi_20_arl': 4.046511627906977},
#   'feature_festering_controvertible_hostler': {'legacy_uniqueness': 0.7362845863276957,
#    'spearman_corr_w_target_nomi_20_mean': -0.004255634348142293,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.22698491101181462,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00025594258177659115,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.14351666964260107,
#    'spearman_corr_w_target_nomi_20_arl': 3.676056338028169},
#   'feature_leukemic_paler_millikan': {'legacy_uniqueness': 0.8078126039703812,
#    'spearman_corr_w_target_nomi_20_mean': -0.0019476552197493957,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.10436022905508201,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00028380220932788423,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.00926877588814144,
#    'spearman_corr_w_target_nomi_20_arl': 3.125748502994012},
#   'feature_subapostolic_dungy_fermion': {'legacy_uniqueness': 0.628546158166948,
#    'spearman_corr_w_target_nomi_20_mean': -0.00041946741389767365,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.020456270103210352,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00025838510446889835,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.016214569582772734,
#    'spearman_corr_w_target_nomi_20_arl': 3.527027027027027},
#   'feature_wale_planned_tolstoy': {'legacy_uniqueness': 0.6605114802463881,
#    'spearman_corr_w_target_nomi_20_mean': -0.0011197636116172225,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.051304179622029544,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00026972267841569034,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.036615678529034634,
#    'spearman_corr_w_target_nomi_20_arl': 4.015384615384615},
#   'feature_bifacial_hexastyle_hemialgia': {'legacy_uniqueness': 0.742114598010152,
#    'spearman_corr_w_target_nomi_20_mean': -0.0012874025983279883,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.05973197061706186,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00029187370786901997,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.031429845106265286,
#    'spearman_corr_w_target_nomi_20_arl': 3.6},
#   'feature_revealable_aeonian_elvira': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0010294277746991324,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.062419477081052895,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00019847675833653468,
#    'spearman_corr_w_target_nomi_20_autocorr': -0.017371516456282626,
#    'spearman_corr_w_target_nomi_20_arl': 3.5510204081632653},
#   'feature_perceivable_gasiform_psammite': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.002735254584173049,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.13312215499810184,
#    'spearman_corr_w_target_nomi_20_reversals': 0.0002782518360285971,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.09675513325003846,
#    'spearman_corr_w_target_nomi_20_arl': 3.3896103896103895},
#   'feature_smugger_hydroponic_farnesol': {'legacy_uniqueness': 0.2962881494155677,
#    'spearman_corr_w_target_nomi_20_mean': -0.0001960521099556528,
#    'spearman_corr_w_target_nomi_20_sharpe': -0.011108966159534049,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00018528358779944777,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.10090446419920754,
#    'spearman_corr_w_target_nomi_20_arl': 3.702127659574468},
#   'feature_apostate_impercipient_knighthood': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': 0.0028256943936665925,
#    'spearman_corr_w_target_nomi_20_sharpe': 0.16043849142068947,
#    'spearman_corr_w_target_nomi_20_reversals': 0.00018942330907551614,
#    'spearman_corr_w_target_nomi_20_autocorr': 0.029019220796921298,
#    'spearman_corr_w_target_nomi_20_arl': 4.31404958677686},
#   'feature_unperfect_implemental_cellarage': {'legacy_uniqueness': 0.0,
#    'spearman_corr_w_target_nomi_20_mean': -0.0005753185875916924,
# ...
#    'feature_cairned_fumiest_ordaining',
#    'feature_calceolate_pudgy_armure',
#    'feature_calculating_unenchanted_microscopium',
#    'feature_calefactive_anapaestic_jerome',
#    'feature_calycled_living_birmingham',
#    'feature_camphorated_spry_freemartin',
#    'feature_caressive_cognate_cubature',
#    'feature_casemated_ibsenian_grantee',
#    'feature_castrated_presented_quizzer',
#    'feature_casuistic_barbarian_monochromy',
#    'feature_centric_shaggier_cranko',
#    'feature_cerebrovascular_weeny_advocate',
#    'feature_chafed_undenominational_backstitch',
#    'feature_chaldean_vixenly_propylite',
#    'feature_chaotic_granitoid_theist',
#    'feature_chartered_conceptual_spitting',
#    'feature_cheering_protonemal_herd',
#    'feature_chelonian_pyknic_delphi',
#    'feature_chopfallen_fasciate_orchidologist',
#    'feature_christadelphian_euclidean_boon',
#    'feature_chuffier_analectic_conchiolin',
#    'feature_churrigueresque_talc_archaicism',
#    'feature_clawed_unwept_adaptability',
#    'feature_clerkish_flowing_chapati',
#    'feature_coalier_typhoid_muntin',
#    'feature_collective_stigmatic_handfasting',
#    'feature_commensurable_industrial_jungfrau',
#    'feature_communicatory_unrecommended_velure',
#    'feature_conceding_ingrate_tablespoonful',
#    'feature_confiscatory_triennial_pelting',
#    'feature_congealed_lee_steek',
#    'feature_congenial_transmigrant_isobel',
#    'feature_congenital_conched_perithecium',
#    'feature_conjugal_postvocalic_rowe',
#    'feature_consecrate_legislative_cavitation',
#    'feature_contaminative_intrusive_tagrag',
#    'feature_continuate_unprocurable_haversine',
#    'feature_contused_festal_geochemistry',
#    'feature_coordinated_undecipherable_gag',
#    'feature_covalent_methodological_brash',
#    'feature_covalent_unreformed_frogbit',
#    'feature_crablike_panniered_gloating',
#    'feature_criticisable_authentical_deprecation',
#    'feature_croupiest_shaded_thermotropism',
#    'feature_ctenoid_moaning_fontainebleau',
#    'feature_culinary_pro_offering',
#    'feature_curling_aurorean_iseult',
#    'feature_curtained_gushier_tranquilizer',
#    'feature_cyrenaic_unschooled_silurian',
#    'feature_decent_solo_stickup',
#    'feature_degenerate_officinal_feasibility',
#    'feature_demisable_expiring_millepede',
#    'feature_demure_groutiest_housedog',
#    'feature_dendritic_prothallium_sweeper',
#    'feature_dentilingual_removed_osmometer',
#    'feature_descendent_decanal_hon',
#    'feature_desiderative_commiserative_epizoa',
#    'feature_designer_notchy_epiploon',
#    'feature_dichasial_hammier_spawner',
#    'feature_dipped_sent_giuseppe',
#    'feature_discrepant_ventral_shicker',
#    'feature_dismaying_chaldean_tallith',
#    'feature_dispiriting_araeostyle_jersey',
#    'feature_diverticular_punjabi_matronship',
#    'feature_doggish_whacking_headscarf',
#    'feature_dovetailed_winy_hanaper',
#    'feature_draconic_contractible_romper',
#    'feature_emmetropic_heraclitean_conducting',
#    'feature_encompassing_skeptical_salience',
#    'feature_endangered_unthreaded_firebrick',
#    'feature_enlightening_mirthful_laurencin',
#    'feature_epicurean_fetal_seising',
#    'feature_epidermic_scruffiest_prosperity',
#    'feature_epitaxial_loathsome_essen',
#    'feature_eruptive_seasoned_pharmacognosy',
#    'feature_escutcheoned_timocratic_kotwal',
#    'feature_euterpean_frazzled_williamsburg',
#    'feature_exacerbating_presentationism_apagoge',
#    'feature_expressed_abhominable_pruning',
#    'feature_extractable_serrulate_swing',
#    'feature_fake_trident_agitator',
#    'feature_faltering_tergal_tip',
#    'feature_farcical_spinal_samantha',
#    'feature_faustian_unventilated_lackluster',
#    'feature_favoring_prescript_unorthodoxy',
#    'feature_festering_controvertible_hostler',
#    'feature_fierier_goofier_follicle',
#    'feature_fissirostral_multifoliate_chillon',
#    'feature_flakiest_fleecy_novelese',
#    'feature_flavourful_seismic_erica',
#    'feature_fleshly_bedimmed_enfacement',
#    'feature_foamy_undrilled_glaciology',
#    'feature_fragrant_fifteen_brian',
#    'feature_frequentative_participial_waft',
#    'feature_fumarolic_known_sharkskin',
#    'feature_fustiest_voiced_janet',
#    'feature_galvanometric_sturdied_billingsgate',
#    'feature_ganoid_osiered_mineralogy',
#    'feature_generative_honorific_tughrik',
#    'feature_glare_factional_assessment',
#    'feature_glyptic_unrubbed_holloway',
#    'feature_gone_honduran_worshipper',
#    'feature_gossamer_placable_wycliffite',
#    'feature_grazed_blameful_desiderative',
#    'feature_greedier_favorable_enthymeme',
#    'feature_groggy_undescried_geosphere',
#    'feature_gullable_sanguine_incongruity',
#    'feature_gutta_exploitive_simpson',
#    'feature_haematoid_runaway_nightjar',
#    'feature_hawkish_domiciliary_duramen',
#    'feature_headhunting_unsatisfied_phenomena',
#    'feature_hellenistic_scraggly_comfort',
#    'feature_helpable_chanciest_fractionisation',
#    'feature_hemispherical_unabsolved_aeolipile',
#    'feature_hendecagonal_deathly_stiver',
#    'feature_hexametric_ventricose_limnology',
#    'feature_hibernating_soritic_croupe',
#    'feature_highland_eocene_berean',
#    'feature_hillier_unpitied_theobromine',
#    'feature_himyarite_tetragonal_deceit',
#    'feature_horizontal_snug_description',
#    'feature_hotfoot_behaviorist_terylene',
#    'feature_huskiest_compartmental_jacquerie',
#    'feature_hydrologic_cymric_nyctophobia',
#    'feature_hypermetropic_unsighted_forsyth',
#    'feature_hypersonic_volcanological_footwear',
#    'feature_hypogastric_effectual_sunlight',
#    'feature_hypothetic_distressing_endemic',
#    'feature_hysteric_mechanized_recklinghausen',
#    'feature_iconomatic_boozier_age',
#    'feature_illiterate_stomachal_terpene',
#    'feature_impractical_endorsed_tide',
#    'feature_incitant_trochoidal_oculist',
#    'feature_incommensurable_diffused_curability',
#    'feature_indefatigable_enterprising_calf',
#    'feature_indentured_communicant_tulipomania',
#    'feature_indirect_concrete_canaille',
#    'feature_induplicate_hoarse_disbursement',
#    'feature_inexpugnable_gleg_candelilla',
#    'feature_inflexed_lamaism_crit',
#    'feature_inhabited_pettier_veinlet',
#    'feature_inhibited_snowiest_drawing',
#    'feature_inseminated_filarial_mesoderm',
#    'feature_insociable_exultant_tatum',
#    'feature_instrumentalist_extrovert_cassini',
#    'feature_integrated_extroversive_ambivalence',
#    'feature_intended_involute_highbinder',
#    'feature_intercalative_helvetian_infirmarian',
#    'feature_interdental_mongolian_anarchism',
#    'feature_intermontane_vertical_moo',
#    'feature_interrogatory_isohyetal_atacamite',
#    'feature_intersubjective_juristic_sagebrush',
#    'feature_intertwined_leeriest_suffragette',
#    'feature_introvert_symphysial_assegai',
#    'feature_intrusive_effluent_hokkaido',
#    'feature_invalid_chromatographic_cornishman',
#    'feature_invalid_extortionary_titillation',
#    'feature_iridic_unpropertied_spline',
#    'feature_irresponsive_compositive_ramson',
#    'feature_irritant_euphuistic_weka',
#    'feature_isotopic_hymenial_starwort',
#    'feature_jerkwater_eustatic_electrocardiograph',
#    'feature_jiggish_tritheist_probity',
#    'feature_juvenalian_paunchy_uniformitarianism',
#    'feature_kerygmatic_splashed_ziegfeld',
#    'feature_koranic_rude_corf',
#    'feature_leaky_maroon_pyrometry',
#    'feature_learned_claustral_quiddity',
#    'feature_leggiest_slaggiest_inez',
#    'feature_leisurable_dehortatory_pretoria',
#    'feature_leukemic_paler_millikan',
#    'feature_levigate_kindly_dyspareunia',
#    'feature_liege_unexercised_ennoblement',
#    'feature_limitable_astable_physiology',
#    'feature_lipogrammatic_blowsier_seismometry',
#    'feature_log_unregenerate_babel',
#    'feature_lordly_lamellicorn_buxtehude',
#    'feature_loricate_cryptocrystalline_ethnology',
#    'feature_lost_quirky_botel',
#    'feature_loyal_fishy_pith',
#    'feature_malacological_differential_defeated',
#    'feature_malagasy_abounding_circumciser',
#    'feature_massed_nonracial_ecclesiologist',
#    'feature_mattery_past_moro',
#    'feature_maximal_unobserving_desalinisation',
#    'feature_mazy_superrefined_punishment',
#    'feature_merovingian_tenebrism_hartshorn',
#    'feature_methylated_necrophilic_serendipity',
#    'feature_midget_noncognizable_plenary',
#    'feature_migrant_reliable_chirurgery',
#    'feature_mined_game_curse',
#    'feature_misanthropic_knurliest_freebooty',
#    'feature_more_hindoo_diageotropism',
#    'feature_mucky_loanable_gastrostomy',
#    'feature_multilinear_sharpened_mouse',
#    'feature_myographic_gawkier_timbale',
#    'feature_naval_edified_decarbonize',
#    'feature_nebule_barmier_bibliomania',
#    'feature_nubblier_plosive_deepening',
#    'feature_nucleophilic_uremic_endogen',
#    'feature_obeisant_vicarial_passibility',
#    'feature_offshore_defamatory_catalog',
#    'feature_outdated_tapered_speciation',
#    'feature_outsized_admonishing_errantry',
#    'feature_oversea_permed_insulter',
#    'feature_ovular_powered_neckar',
#    'feature_padded_peripteral_pericranium',
#    'feature_palatalized_unsucceeded_induration',
#    'feature_palmy_superfluid_argyrodite',
#    'feature_pansophic_merino_pintado',
#    'feature_paraffinoid_irreplevisable_ombu',
#    'feature_paramagnetic_complex_gish',
#    'feature_passerine_ultraist_neon',
#    'feature_patristical_analysable_langouste',
#    'feature_peaty_vulgar_branchia',
#    'feature_peculiar_sheenier_quintal',
#    'feature_peltate_okay_info',
#    'feature_perceivable_gasiform_psammite',
#    'feature_perigean_bewitching_thruster',
#    'feature_periscopic_thirteenth_cartage',
#    'feature_permanent_cottony_ballpen',
#    'feature_pert_performative_hormuz',
#    'feature_petitionary_evanescent_diallage',
#    'feature_phellogenetic_vibrational_jocelyn',
#    'feature_piffling_inflamed_jupiter',
#    'feature_planar_unessential_bride',
#    'feature_planned_superimposed_bend',
#    'feature_plexiform_won_elk',
#    'feature_polaroid_squalliest_applause',
#    'feature_precooled_inoperable_credence',
#    'feature_puberulent_nondescript_laparoscope',
#    'feature_publishable_apiarian_rollick',
#    'feature_quadratic_untouched_liberty',
#    'feature_questionable_diplex_caesarist',
#    'feature_quinsied_increased_braincase',
#    'feature_ratlike_matrilinear_collapsability',
#    'feature_recidivism_petitory_methyltestosterone',
#    'feature_reclaimed_fallibilist_turpentine',
#    'feature_reclinate_cruciform_lilo',
#    'feature_reconciling_dauby_database',
#    'feature_reduplicate_conoid_albite',
#    'feature_refreshed_untombed_skinhead',
#    'feature_reminiscent_unpained_ukulele',
#    'feature_renegade_undomestic_milord',
#    'feature_reported_slimy_rhapsody',
#    'feature_reserved_cleanable_soldan',
#    'feature_restricted_aggregately_workmanship',
#    'feature_resuscitative_communicable_brede',
#    'feature_retinoscopy_flinty_wool',
#    'feature_revealable_aeonian_elvira',
#    'feature_revitalizing_dashing_photomultiplier',
#    'feature_rheumy_epistemic_prancer',
#    'feature_rimmed_conditional_archipelago',
#    'feature_roasting_slaked_reposition',
#    'feature_roiling_trimeric_kurosawa',
#    'feature_rowable_unshod_noise',
#    'feature_rubblier_chlorotic_stogy',
#    'feature_ruffianly_uncommercial_anatole',
#    'feature_rural_inquisitional_trotline',
#    'feature_rusted_unassisting_menaquinone',
#    'feature_ruthenian_uncluttered_vocalizing',
#    'feature_salian_suggested_ephemeron',
#    'feature_sallowish_cognisant_romaunt',
#    'feature_scenic_cormophytic_bilirubin',
#    'feature_scenographical_dissentient_trek',
#    'feature_scorbutic_intellectualism_mongoloid',
#    'feature_scrobiculate_unexcitable_alder',
#    'feature_seamier_jansenism_inflator',
#    'feature_seclusive_emendatory_plangency',
#    'feature_seemlier_reorient_monandry',
#    'feature_severe_tricky_pinochle',
#    'feature_sixteen_inbreed_are',
#    'feature_sludgy_implemental_sicily',
#    'feature_smoggy_niftiest_lunch',
#    'feature_smugger_hydroponic_farnesol',
#    'feature_softish_unseparated_caudex',
#    'feature_sorted_ignitable_sagitta',
#    'feature_spagyric_echt_alum',
#    'feature_spookiest_expedite_overnighter',
#    'feature_springlike_crackjaw_bheesty',
#    'feature_squishiest_unsectarian_support',
#    'feature_stelar_balmiest_pellitory',
#    'feature_stereotypic_ebracteate_louise',
#    'feature_strychnic_structuralist_chital',
#    'feature_stylistic_honduran_comprador',
#    'feature_subapostolic_dungy_fermion',
#    'feature_subdued_spiffier_kano',
#    'feature_subglobular_unsalable_patzer',
#    'feature_substandard_permissible_paresthesia',
#    'feature_sudsy_polymeric_posteriority',
#    'feature_supergene_legible_antarthritic',
#    'feature_synoptic_botryose_earthwork',
#    'feature_syrian_coital_counterproof',
#    'feature_tarry_meet_chapel',
#    'feature_telephonic_shakable_bollock',
#    'feature_terrific_epigamic_affectivity',
#    'feature_tittering_virgilian_decliner',
#    'feature_together_suppositive_aster',
#    'feature_tonal_graptolitic_corsac',
#    'feature_tortured_arsenical_arable',
#    'feature_torturesome_estimable_preferrer',
#    'feature_tossing_denominative_threshing',
#    'feature_trabeate_eutherian_valedictory',
#    'feature_tranquilizing_abashed_glyceria',
#    'feature_transmontane_clerkly_value',
#    'feature_travelled_semipermeable_perruquier',
#    'feature_tribal_germinable_yarraman',
#    'feature_trim_axial_suffocation',
#    'feature_unaimed_yonder_filmland',
#    'feature_unamazed_tumular_photomicrograph',
#    'feature_unapplicable_jerkiest_klemperer',
#    'feature_unbeaten_orological_dentin',
#    'feature_unbreakable_nosological_comedian',
#    'feature_unburied_exponent_pace',
#    'feature_uncertified_myrmecological_nagger',
#    'feature_uncharged_unovercome_smolder',
#    'feature_unco_terefah_thirster',
#    'feature_uncomplimentary_malignant_scoff',
#    'feature_uncompromising_fancy_kyle',
#    'feature_uncurtailed_translucid_coccid',
#    'feature_undescribed_methylic_friday',
#    'feature_undetermined_idle_aftergrowth',
#    'feature_undirected_perdu_ylem',
#    'feature_undisguised_whatever_gaul',
#    'feature_undivorced_unsatisfying_praetorium',
#    'feature_undrossy_serpentiform_sack',
#    'feature_unextinct_smectic_isa',
#    'feature_uninclosed_handcrafted_springing',
#    'feature_univalve_abdicant_distrail',
#    'feature_unknown_reusable_cabbage',
#    'feature_unlawful_superintendent_brunet',
#    'feature_unlivable_morbific_traveling',
#    'feature_unliving_bit_bengaline',
#    'feature_unluckiest_mulley_benzyl',
#    'feature_unmalleable_resistant_kingston',
#    'feature_unmodernized_vasodilator_galenist',
#    'feature_unmoved_alt_spoonerism',
#    'feature_unnetted_bay_premillennialist',
#    'feature_unnourishing_indiscreet_occiput',
#    'feature_unperfect_implemental_cellarage',
#    'feature_unrated_intact_balmoral',
#    'feature_unrelieved_rawish_cement',
#    'feature_unrequired_waxing_skeptic',
#    'feature_unscheduled_malignant_shingling',
#    'feature_unsparing_moralistic_commissary',
#    'feature_unsparred_scarabaeid_anthologist',
#    'feature_unspotted_practiced_gland',
#    'feature_unstacked_trackable_blizzard',
#    'feature_unsurveyed_boyish_aleph',
#    'feature_unsurveyed_chopped_feldspathoid',
#    'feature_untellable_penal_allegorization',
#    'feature_untouchable_unsolvable_agouti',
#    'feature_untrimmed_monaxial_accompanist',
#    'feature_untumbled_histologic_inion',
#    'feature_unvaried_social_bangkok',
#    'feature_unweary_congolese_captain',
#    'feature_uretic_seral_decoding',
#    'feature_urochordal_swallowed_curn',
#    'feature_vedic_mitral_swiz',
#    'feature_venatic_intermetallic_darling',
#    'feature_vestmental_hoofed_transpose',
#    'feature_vizierial_courtlier_hampton',
#    'feature_volitional_ascensive_selfhood',
#    'feature_voltairean_consolidative_parallel',
#    'feature_voltairean_dyslogistic_epagoge',
#    'feature_vulcanological_sepulchral_spean',
#    'feature_wale_planned_tolstoy',
#    'feature_westering_immunosuppressive_crapaud',
#    'feature_whistleable_unbedimmed_chokey',
#    'feature_whitened_remanent_blast',
#    'feature_whopping_eminent_attempter',
#    'feature_wieldable_defiled_aperitive',
#    'feature_wombed_reverberatory_colourer',
#    'feature_zarathustrian_albigensian_itch',
#    'feature_zymotic_varnished_mulga']}}

# %%
#hide
# Remove contents (for tests)
numer_classic_downloader.remove_base_directory()
# Out:
# ⚠ Deleting directory for 'NumeraiClassicDownloader' ⚠
# Path:
# '/Users/clepelaars/Desktop/crowdcent/repositories/numerai-blocks/nbs/test_numclassic_train'

# %% [markdown]
# __For the training example the directory structure will be:__

# %%
#hide_input
console = Console(record=True, width=100)

tree = Tree(f":file_folder: {train_base_directory} (base_directory)", guide_style="bold bright_black")
folder_tree = tree.add(":page_facing_up: features.json")
train_val_tree = tree.add(":file_folder: train_val")
train_val_tree.add(':page_facing_up: numerai_training_data.parquet')
train_val_tree.add(':page_facing_up: numerai_validation_data.parquet')

console.print(tree)
# Out:
# 📁 test_numclassic_train (base_directory)
# ┣━━ 📄 features.json
# ┗━━ 📁 train_val
#     ┣━━ 📄 numerai_training_data.parquet
#     ┗━━ 📄 numerai_validation_data.parquet

# %% [markdown]
# #### Inference

# %%
#slow
# initialization
inference_base_directory = "test_numclassic_inference"
numer_classic_downloader = NumeraiClassicDownloader(inference_base_directory)

# Download tournament (inference) data
numer_classic_downloader.download_inference_data("inference", version=2, int8=False)

# Remove folder when done with inference
numer_classic_downloader.remove_base_directory()
# Out:
# No existing directory found at 'test_numclassic_inference'. Creating directory...
# 📁 Downloading inference data for round '297'.
# 📁 Downloading 'numerai_tournament_data.parquet' 📁
# 2022-01-06 13:08:21,980 INFO numerapi.utils: starting download
# test_numclassic_inference/inference/numerai_tournament_data.parquet: 582MB [06:16, 1.55MB/s]
# ⚠ Deleting directory for 'NumeraiClassicDownloader' ⚠
# Path: '/Users/clepelaars/Desktop/crowdcent/repositories/numerai-blocks/nbs/test_numclassic_in
# ference'

# %% [markdown]
# __For the inference example the directory structure will be:__

# %%
#hide_input
console = Console(record=True, width=100)

tree = Tree(f":file_folder: {inference_base_directory} (base_directory)", guide_style="bold bright_black")
inference_tree = tree.add(":file_folder: inference")
inference_tree.add(':page_facing_up: numerai_tournament_data.parquet')

console.print(tree)
# Out:
# 📁 test_numclassic_inference (base_directory)
# ┗━━ 📁 inference
#     ┗━━ 📄 numerai_tournament_data.parquet

# %% [markdown]
# ## 3. Yahoo Finance

# %% [markdown]
# ## 4. FinnHub

# %% [markdown]
# ## 5. Bloomberg?

# %% [markdown]
# ## 6. Custom Downloader

# %% [markdown]
# We invite the Numerai Community to implement new downloaders using interesting APIs. This is especially important for creating innovative Numerai Signals models.
#
# A new Downloader can be created by inheriting from `BaseDownloader`. One also should implement `download_inference_data` and `download_training_data` so we have a common interface for downloading data.

# %%
class AwesomeCustomDownloader(BaseDownloader):
    """
    Download awesome financial data from who knows where.

    :param directory_path: Base folder to download files to.
    """
    def __init__(self, directory_path: str, *args, **kwargs):
        super(AwesomeCustomDownloader, self).__init__(directory_path=directory_path)

    def download_inference_data(self, *args, **kwargs):
        """ (minimal) weekly inference downloading here. """
        ...

    def download_training_data(self, *args, **kwargs):
        """ Training dataset downloading here. """
        ...

# %%
#hide
# Run this cell to sync all changes with library
from nbdev.export import notebook2script; notebook2script()
# Out:
# Converted 00_download.ipynb.
# Converted 01_dataloaders.ipynb.
# Converted 02_dataset.ipynb.
# Converted 03_preprocessing.ipynb.
# Converted 04a_model.ipynb.
# Converted 04b_modelpipeline.ipynb.
# Converted 05_postprocessing.ipynb.
# Converted 06_prediction_dataset.ipynb.
# Converted 07_evaluation.ipynb.
# Converted 08_key.ipynb.
# Converted 09_submission.ipynb.
# Converted index.ipynb.
